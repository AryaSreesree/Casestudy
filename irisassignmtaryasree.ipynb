# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#path = '/content/drive/MyDrive/irisdata.csv'
df = pd.read_csv("iris.csv")

# %%
df.head(2)
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
df.hist(figsize=(10,10), bins=10 , color="purple")
plt.show()

# %%
sns.scatterplot(x="SL", y="PL", hue="Classification", palette= "dark", data =df ,cmap="coolwarm")
plt.show()

# %%
sns.scatterplot(x="SW", y="PW", hue="Classification", palette= "dark", data =df ,cmap="coolwarm")
plt.show()

# %%
sns.pairplot(df, hue= "Classification", palette="dark")
plt.show()
